# %%
import pandas as pd
import numpy as np
import sys
import matplotlib.pyplot as plt
import math
from sklearn.svm import SVR, LinearSVR, SVC, LinearSVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold
from sklearn.linear_model import Lasso
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import ExtraTreesClassifier, RandomForestClassifier

# %%
sys.path.insert(0, r'../../src')
from function_cache import *

# %%
T_0min = pd.read_csv('../../data/processed/price_before_close/T_0min.csv', index_col='Trading_Day', parse_dates=True)
TF_0min = pd.read_csv('../../data/processed/price_before_close/TF_0min.csv', index_col='Trading_Day', parse_dates=True)
T_5min = pd.read_csv('../../data/processed/price_before_close/T_5min.csv', index_col='Trading_Day', parse_dates=True)
TF_5min = pd.read_csv('../../data/processed/price_before_close/TF_5min.csv', index_col='Trading_Day', parse_dates=True)
T_10min = pd.read_csv('../../data/processed/price_before_close/T_10min.csv', index_col='Trading_Day', parse_dates=True)
TF_10min = pd.read_csv('../../data/processed/price_before_close/TF_10min.csv', index_col='Trading_Day', parse_dates=True)
T_15min = pd.read_csv('../../data/processed/price_before_close/T_15min.csv', index_col='Trading_Day', parse_dates=True)
TF_15min = pd.read_csv('../../data/processed/price_before_close/TF_15min.csv', index_col='Trading_Day', parse_dates=True)

# %%
T_features = pd.read_csv('../../data/processed/candidate_features/T_features.csv', index_col=0)
TF_features = pd.read_csv('../../data/processed/candidate_features/TF_features.csv', index_col=0)
T_spread_change = pd.read_csv('../../data/processed/different_ys/T_spread_change.csv', index_col=0)
TF_spread_change = pd.read_csv('../../data/processed/different_ys/TF_spread_change.csv', index_col=0)

# %%
features = pd.concat([T_features, TF_features])
spread_change = pd.concat([T_spread_change, TF_spread_change])

# %%
X = features.values
y = spread_change['0min_0min'].values

scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
alphas = [0.001, 0.002, 0.005, 0.01, 0.015, 0.02, 0.05, 0.1]

# %%
def lasso(X, y, feature_names, alphas):
    '''
    Takes in a list of alphas. Outputs a dataframe containing the coefficients of lasso regressions from each alpha.
    '''
    coef_df = pd.DataFrame(index=feature_names)
    coef_df.index.name = 'feature'
    pred_df = pd.DataFrame(index=features.index)
    pred_df.index.name = 'feature'
    
    for alpha in alphas:

        lasso = Lasso(alpha=alpha)
        lasso.fit(X, y)

        column_name = 'Alpha = %f' % alpha

        # Create a column of coefficient values
        coef_df[column_name] = lasso.coef_
        pred_df[column_name] = lasso.predict(X)
  
    coef_df = coef_df.replace(0, np.nan)
    
    return coef_df, pred_df

# %%
coef_df, pred_df = lasso(X, y, list(features.columns), alphas)

# %%
coef_df
# Out:
#                                 Alpha = 0.001000  Alpha = 0.002000  \
# feature
# 5d_spread_change                       -0.039580         -0.044372
# 10d_spread_change                      -0.189397         -0.180176
# 15d_spread_change                       0.244216          0.228150
# 20d_spread_change                       0.018370          0.021606
# 10d_act_price_exp_mva                   0.009944          0.031015
# -1d_corr_act_price_def_OI                    NaN               NaN
# -1d_corr_def_price_def_OI              -0.177268         -0.158584
# 10d_spread_std_divided_by_std           0.134020          0.108698
# 10d_current_price                      -0.001669               NaN
# 1d_z_diff_act_price_def_price          -0.094975         -0.099472
# -1d_corr_act_price_def_volume                NaN               NaN
# -1d_corr_def_price_def_volume                NaN               NaN
# 10d_current_spread                      0.038150          0.028390
# -1d_std                                 0.086196          0.076934
# -1d_corr_act_price_def_price            0.001320          0.003004
# -1d_corr_act_OI_def_volume             -0.182496         -0.127500
# -1d_corr_act_OI_def_OI                  0.068848          0.029421
# -1d_corr_def_volume_def_OI             -0.095393         -0.051766
# -1d_corr_def_OI_spread                  0.137070          0.096441
# -1d_corr_def_volume_spread             -0.181985         -0.112753
# 1d_z_diff_act_price_def_OI              0.175661          0.150480
# -1d_corr_act_volume_def_volume         -0.193548         -0.121723
# -1d_corr_act_volume_def_OI              0.212773          0.140444
# -1d_corr_act_price_act_OI                    NaN               NaN
# 1d_z_diff_act_volume_act_OI            -0.015634               NaN
# 10d_def_volume_exp_mva                  0.009168          0.005198
# -1d_corr_act_OI_spread                  0.062822          0.054773
# -1d_corr_def_price_spread               0.038656          0.024750
#
#                                 Alpha = 0.005000  Alpha = 0.010000  \
# feature
# 5d_spread_change                       -0.040157         -0.000778
# 10d_spread_change                      -0.119424               NaN
# 15d_spread_change                       0.140678               NaN
# 20d_spread_change                       0.033092               NaN
# 10d_act_price_exp_mva                   0.050021          0.013561
# -1d_corr_act_price_def_OI                    NaN               NaN
# -1d_corr_def_price_def_OI              -0.100379         -0.081949
# 10d_spread_std_divided_by_std           0.055459          0.035052
# 10d_current_price                            NaN               NaN
# 1d_z_diff_act_price_def_price          -0.096595         -0.082802
# -1d_corr_act_price_def_volume          -0.010929               NaN
# -1d_corr_def_price_def_volume                NaN               NaN
# 10d_current_spread                      0.016944               NaN
# -1d_std                                 0.082922          0.066611
# -1d_corr_act_price_def_price                 NaN               NaN
# -1d_corr_act_OI_def_volume             -0.064637         -0.033237
# -1d_corr_act_OI_def_OI                       NaN               NaN
# -1d_corr_def_volume_def_OI                   NaN               NaN
# -1d_corr_def_OI_spread                  0.044749          0.094470
# -1d_corr_def_volume_spread                   NaN               NaN
# 1d_z_diff_act_price_def_OI              0.110251          0.099286
# -1d_corr_act_volume_def_volume         -0.008336               NaN
# -1d_corr_act_volume_def_OI              0.025761          0.025463
# -1d_corr_act_price_act_OI               0.009959               NaN
# 1d_z_diff_act_volume_act_OI             0.006621          0.013950
# 10d_def_volume_exp_mva                  0.000803          0.007464
# -1d_corr_act_OI_spread                  0.019525               NaN
# -1d_corr_def_price_spread               0.005453               NaN
#
#                                 Alpha = 0.015000  Alpha = 0.020000  \
# feature
# 5d_spread_change                             NaN               NaN
# 10d_spread_change                            NaN               NaN
# 15d_spread_change                            NaN               NaN
# 20d_spread_change                       0.002011          0.005613
# 10d_act_price_exp_mva                   0.010306          0.003146
# -1d_corr_act_price_def_OI                    NaN               NaN
# -1d_corr_def_price_def_OI              -0.066705         -0.052994
# 10d_spread_std_divided_by_std           0.022921          0.011471
# 10d_current_price                            NaN               NaN
# 1d_z_diff_act_price_def_price          -0.069358         -0.057075
# -1d_corr_act_price_def_volume                NaN               NaN
# -1d_corr_def_price_def_volume                NaN               NaN
# 10d_current_spread                           NaN               NaN
# -1d_std                                 0.063349          0.058186
# -1d_corr_act_price_def_price                 NaN               NaN
# -1d_corr_act_OI_def_volume             -0.015760               NaN
# -1d_corr_act_OI_def_OI                       NaN               NaN
# -1d_corr_def_volume_def_OI                   NaN               NaN
# -1d_corr_def_OI_spread                  0.095060          0.092591
# -1d_corr_def_volume_spread                   NaN               NaN
# 1d_z_diff_act_price_def_OI              0.083359          0.075571
# -1d_corr_act_volume_def_volume               NaN               NaN
# -1d_corr_act_volume_def_OI              0.020818          0.015748
# -1d_corr_act_price_act_OI                    NaN               NaN
# 1d_z_diff_act_volume_act_OI             0.009862          0.005617
# 10d_def_volume_exp_mva                       NaN               NaN
# -1d_corr_act_OI_spread                       NaN               NaN
# -1d_corr_def_price_spread                    NaN               NaN
#
#                                 Alpha = 0.050000  Alpha = 0.100000
# feature
# 5d_spread_change                             NaN               NaN
# 10d_spread_change                            NaN               NaN
# 15d_spread_change                            NaN               NaN
# 20d_spread_change                       0.000631               NaN
# 10d_act_price_exp_mva                        NaN               NaN
# -1d_corr_act_price_def_OI                    NaN               NaN
# -1d_corr_def_price_def_OI                    NaN               NaN
# 10d_spread_std_divided_by_std                NaN               NaN
# 10d_current_price                            NaN               NaN
# 1d_z_diff_act_price_def_price          -0.010371               NaN
# -1d_corr_act_price_def_volume                NaN               NaN
# -1d_corr_def_price_def_volume                NaN               NaN
# 10d_current_spread                           NaN               NaN
# -1d_std                                 0.036764               NaN
# -1d_corr_act_price_def_price                 NaN               NaN
# -1d_corr_act_OI_def_volume                   NaN               NaN
# -1d_corr_act_OI_def_OI                       NaN               NaN
# -1d_corr_def_volume_def_OI                   NaN               NaN
# -1d_corr_def_OI_spread                  0.074007          0.029655
# -1d_corr_def_volume_spread                   NaN               NaN
# 1d_z_diff_act_price_def_OI              0.022461               NaN
# -1d_corr_act_volume_def_volume               NaN               NaN
# -1d_corr_act_volume_def_OI              0.001548               NaN
# -1d_corr_act_price_act_OI                    NaN               NaN
# 1d_z_diff_act_volume_act_OI                  NaN               NaN
# 10d_def_volume_exp_mva                       NaN               NaN
# -1d_corr_act_OI_spread                       NaN               NaN
# -1d_corr_def_price_spread                    NaN               NaN

# %%
pred_df
# Out:
#          Alpha = 0.001000  Alpha = 0.002000  Alpha = 0.005000  \
# feature
# T1509            0.380031          0.368227          0.346133
# T1512            0.619809          0.580046          0.481844
# T1603            0.361122          0.368750          0.373991
# T1606            0.063370          0.030490          0.039280
# T1609           -0.075527         -0.050917         -0.007346
# T1612            0.323959          0.331051          0.348546
# T1703            0.495404          0.483449          0.432675
# T1706           -0.448235         -0.411899         -0.316521
# T1709            0.008070         -0.029425         -0.120441
# T1712            0.110075          0.102102          0.085524
# T1803            0.063970          0.074192          0.099171
# T1806            0.171597          0.154225          0.136860
# T1809           -0.016526          0.006143          0.050642
# T1812            0.008044          0.011150         -0.008591
# T1903            0.325501          0.308385          0.294245
# T1906            0.195792          0.203730          0.211307
# TF1312          -0.088720         -0.077537         -0.076843
# TF1403          -0.290974         -0.283597         -0.254613
# TF1406          -0.151831         -0.122989         -0.083704
# TF1409           0.024233         -0.012153         -0.046280
# TF1412          -0.053166         -0.044753         -0.019331
# TF1503           0.073088          0.069272          0.039526
# TF1506           0.156337          0.183065          0.234751
# TF1509           0.120733          0.141649          0.193649
# TF1512           0.257386          0.251318          0.229760
# TF1603           0.128826          0.142728          0.146479
# TF1606           0.059746          0.069650          0.064902
# TF1609          -0.123180         -0.112029         -0.079164
# TF1612           0.343303          0.302751          0.222980
# TF1703           0.543432          0.528647          0.498936
# TF1706          -0.374397         -0.342547         -0.283500
# TF1709           0.001741         -0.055479         -0.138760
# TF1712          -0.174620         -0.163275         -0.134195
# TF1803           0.194962          0.201998          0.202121
# TF1806          -0.028963         -0.007835          0.055243
