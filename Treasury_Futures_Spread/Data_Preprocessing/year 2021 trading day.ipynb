# %%
import numpy as np
import pandas as pd

# %%
wind = pd.read_csv('E:/cta_daily/data/raw/meta_data/wind_trading_day.csv', index_col=0, parse_dates=True)

# %%
trading_day = pd.DataFrame(index=pd.bdate_range('2021-01-01', '2021-12-31'))
trading_day.index.name = 'Trading_Day'

# %%
trading_day.to_csv('../data/raw/meta_data/trading_day_2021.csv')
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   """Entry point for launching an IPython kernel.

# %%
trading_day
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
wind
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
trading = pd.concat([wind, trading_day], axis=0)

# %%
trading.to_csv('../data/raw/meta_data/trading_day.csv')
